# %% [markdown]
# # Measuring performance: variable_background_trees_humans

# %% [markdown]
# ### 150k_240

# %%
import pickle
import numpy as np

test_setting = 'variable_background_trees_humans'

model_path = 'data/Train_Supervized_model_150k_240.h5'
save_name = model_path +'%'+test_setting +'%pickle'
print('File is:', save_name)
print('*'*50)

with open(save_name, 'rb') as handle:
    data = pickle.load(handle)

[time_taken, total_rewards, local_steps_mean, rewards_x, rewards_y, black_rewards] = data
print('Total episodes:', len(total_rewards))
print('Avg Time taken:', int(np.mean(time_taken)*1000),  int(np.std(time_taken)*1000))
print('local_steps_mean is:', int(np.mean(local_steps_mean)), int(np.std(local_steps_mean)))
print('% Tracking is:', round(np.mean(local_steps_mean)/20, 1))

model_path = 'data/Train_Supervized_model_150k_240_2.h5'
save_name = model_path +'%'+test_setting +'%pickle'
print('File is:', save_name)
print('*'*50)

with open(save_name, 'rb') as handle:
    data = pickle.load(handle)

[time_taken2, total_rewards2, local_steps_mean2, rewards_x2, rewards_y2, black_rewards2] = data
print('Total episodes:', len(total_rewards2))
print('Avg Time taken:', int(np.mean(time_taken2)*1000),  int(np.std(time_taken2)*1000))
print('local_steps_mean is:', int(np.mean(local_steps_mean2)), int(np.std(local_steps_mean2)))
print('% Tracking is:', round(np.mean(local_steps_mean2)/20, 1))

model_path = 'data/Train_Supervized_model_150k_240_3.h5'
save_name = model_path +'%'+test_setting +'%pickle'
print('File is:', save_name)
print('*'*50)

with open(save_name, 'rb') as handle:
    data = pickle.load(handle)

[time_taken3, total_rewards3, local_steps_mean3, rewards_x3, rewards_y3, black_rewards3] = data
print('Total episodes:', len(total_rewards3))
print('Avg Time taken:', int(np.mean(time_taken3)*1000),  int(np.std(time_taken3)*1000))
print('local_steps_mean is:', int(np.mean(local_steps_mean3)), int(np.std(local_steps_mean3)))
print('% Tracking is:', round(np.mean(local_steps_mean3)/20, 1))


time_taken = np.hstack((time_taken, time_taken2, time_taken3)) 
total_rewards = np.hstack((total_rewards, total_rewards2, total_rewards3)) 
local_steps_mean = np.hstack((local_steps_mean, local_steps_mean2, local_steps_mean3)) 
rewards_x = np.hstack((rewards_x, rewards_x2, rewards_x3)) 
rewards_y = np.hstack((rewards_y, rewards_y2, rewards_y3)) 
black_rewards = np.hstack((black_rewards, black_rewards2, black_rewards3)) 

print('*'*100)

print('*'*100)


print('Total episodes:', len(total_rewards))
print('Avg Time taken:', int(np.mean(time_taken)*1000),  int(np.std(time_taken)*1000))
print('*'*50)

print('Average Reward is:', round(np.mean(total_rewards),2), round(np.std(total_rewards),2))
print('local_steps_mean is:', int(np.mean(local_steps_mean)), int(np.std(local_steps_mean)))
print('rewards_x mean is:', round(np.mean(rewards_x),2), round(np.std(rewards_x),2))
print('rewards_y mean is:', round(np.mean(rewards_y),2), round(np.std(rewards_y),2))
print('black_rewards mean is:', round(np.mean(black_rewards),2), round(np.std(black_rewards),2))

print('*'*50)
#print(round(np.mean(local_steps_mean)/20, 2), int(np.mean(total_rewards)), round(np.mean(rewards_x),2), round(np.mean(rewards_y),2), round(np.mean(black_rewards),2))

print(round(np.mean(local_steps_mean)/20, 1), round(np.mean(rewards_x),2), round(np.mean(rewards_y),2), round(np.mean(black_rewards),2))
# Out:
# File is: data/Train_Supervized_model_150k_240.h5%variable_background_trees_humans%pickle
# **************************************************
# Total episodes: 100
# Avg Time taken: 29 6
# local_steps_mean is: 1686 551
# % Tracking is: 84.3
# File is: data/Train_Supervized_model_150k_240_2.h5%variable_background_trees_humans%pickle
# **************************************************
# Total episodes: 100
# Avg Time taken: 31 8
# local_steps_mean is: 1644 600
# % Tracking is: 82.2
# File is: data/Train_Supervized_model_150k_240_3.h5%variable_background_trees_humans%pickle
# **************************************************
# Total episodes: 100
# Avg Time taken: 29 4
# local_steps_mean is: 1617 612
# % Tracking is: 80.9
# ****************************************************************************************************
# ****************************************************************************************************
# Total episodes: 300
# Avg Time taken: 30 6
# ...

# %% [markdown]
# ### 100k_240

# %%
import pickle
import numpy as np

test_setting = 'variable_background_trees_humans'
model_path = 'data/Train_Supervized_model_100k_240.h5'

save_name = model_path +'%'+test_setting +'%pickle'

print('File is:', save_name)

print('*'*50)

with open(save_name, 'rb') as handle:
    data = pickle.load(handle)


[time_taken, total_rewards, local_steps_mean, rewards_x, rewards_y, black_rewards] = data

print('Total episodes:', len(total_rewards))
print('Avg Time taken:', int(np.mean(time_taken)*1000),  int(np.std(time_taken)*1000))
print('local_steps_mean is:', int(np.mean(local_steps_mean)), int(np.std(local_steps_mean)))
print('black_rewards mean is:', round(np.mean(black_rewards),2), round(np.std(black_rewards),2))
print('*'*50)



model_path = 'data/Train_Supervized_model_100k_240_2.h5'
save_name = model_path +'%'+test_setting +'%pickle'
print('File is:', save_name)
print('*'*50)

with open(save_name, 'rb') as handle:
    data = pickle.load(handle)

[time_taken2, total_rewards2, local_steps_mean2, rewards_x2, rewards_y2, black_rewards2] = data
print('Total episodes:', len(total_rewards2))
print('Avg Time taken:', int(np.mean(time_taken2)*1000),  int(np.std(time_taken2)*1000))
print('local_steps_mean is:', int(np.mean(local_steps_mean2)), int(np.std(local_steps_mean2)))
print('black_rewards mean is:', round(np.mean(black_rewards2),2), round(np.std(black_rewards2),2))



model_path = 'data/Train_Supervized_model_100k_240_3.h5'
save_name = model_path +'%'+test_setting +'%pickle'
print('File is:', save_name)
print('*'*50)

with open(save_name, 'rb') as handle:
    data = pickle.load(handle)

[time_taken3, total_rewards3, local_steps_mean3, rewards_x3, rewards_y3, black_rewards3] = data
print('Total episodes:', len(total_rewards3))
print('Avg Time taken:', int(np.mean(time_taken3)*1000),  int(np.std(time_taken3)*1000))
print('local_steps_mean is:', int(np.mean(local_steps_mean3)), int(np.std(local_steps_mean3)))
print('black_rewards mean is:', round(np.mean(black_rewards3),2), round(np.std(black_rewards3),2))


time_taken = np.hstack((time_taken, time_taken2, time_taken3)) 
total_rewards = np.hstack((total_rewards, total_rewards2, total_rewards3)) 
local_steps_mean = np.hstack((local_steps_mean, local_steps_mean2, local_steps_mean3)) 
rewards_x = np.hstack((rewards_x, rewards_x2, rewards_x3)) 
rewards_y = np.hstack((rewards_y, rewards_y2, rewards_y3)) 
black_rewards = np.hstack((black_rewards, black_rewards2, black_rewards3)) 

print('*'*100)


print('*'*100)



print('Average Reward is:', round(np.mean(total_rewards),2), round(np.std(total_rewards),2))
print('local_steps_mean is:', int(np.mean(local_steps_mean)), int(np.std(local_steps_mean)))
print('rewards_x mean is:', round(np.mean(rewards_x),2), round(np.std(rewards_x),2))
print('rewards_y mean is:', round(np.mean(rewards_y),2), round(np.std(rewards_y),2))
print('black_rewards mean is:', round(np.mean(black_rewards),2), round(np.std(black_rewards),2))

print('*'*50)
#print(round(np.mean(local_steps_mean)/20, 2), int(np.mean(total_rewards)), round(np.mean(rewards_x),2), round(np.mean(rewards_y),2), round(np.mean(black_rewards),2))

print(round(np.mean(local_steps_mean)/20, 1), round(np.mean(rewards_x),2), round(np.mean(rewards_y),2), round(np.mean(black_rewards),2))
# Out:
# File is: data/Train_Supervized_model_100k_240.h5%variable_background_trees_humans%pickle
# **************************************************
# Total episodes: 100
# Avg Time taken: 29 6
# local_steps_mean is: 1562 601
# black_rewards mean is: 0.29 0.11
# **************************************************
# File is: data/Train_Supervized_model_100k_240_2.h5%variable_background_trees_humans%pickle
# **************************************************
# Total episodes: 100
# Avg Time taken: 30 6
# local_steps_mean is: 1613 620
# black_rewards mean is: 0.28 0.11
# File is: data/Train_Supervized_model_100k_240_3.h5%variable_background_trees_humans%pickle
# **************************************************
# Total episodes: 100
# Avg Time taken: 29 4
# local_steps_mean is: 1711 512
# black_rewards mean is: 0.32 0.13
# ****************************************************************************************************
# ...

# %% [markdown]
# ### 50k_240

# %%
import pickle
import numpy as np

test_setting = 'variable_background_trees_humans'
model_path = 'data/Train_Supervized_model_50k_240.h5'

save_name = model_path +'%'+test_setting +'%pickle'



print('File is:', save_name)

print('*'*50)

with open(save_name, 'rb') as handle:
    data = pickle.load(handle)


[time_taken, total_rewards, local_steps_mean, rewards_x, rewards_y, black_rewards] = data

print('Total episodes:', len(total_rewards))
print('Avg Time taken:', int(np.mean(time_taken)*1000),  int(np.std(time_taken)*1000))
print('local_steps_mean is:', int(np.mean(local_steps_mean)), int(np.std(local_steps_mean)))
print('% Tracking is:', round(np.mean(local_steps_mean)/20, 1))

print('*'*50)



model_path = 'data/Train_Supervized_model_50k_240_2.h5'
save_name = model_path +'%'+test_setting +'%pickle'
print('File is:', save_name)
print('*'*50)

with open(save_name, 'rb') as handle:
    data = pickle.load(handle)

[time_taken2, total_rewards2, local_steps_mean2, rewards_x2, rewards_y2, black_rewards2] = data
print('Total episodes:', len(total_rewards2))
print('Avg Time taken:', int(np.mean(time_taken2)*1000),  int(np.std(time_taken2)*1000))
print('local_steps_mean is:', int(np.mean(local_steps_mean2)), int(np.std(local_steps_mean2)))
print('% Tracking is:', round(np.mean(local_steps_mean2)/20, 1))



model_path = 'data/Train_Supervized_model_50k_240_3.h5'
save_name = model_path +'%'+test_setting +'%pickle'
print('File is:', save_name)
print('*'*50)

with open(save_name, 'rb') as handle:
    data = pickle.load(handle)

[time_taken3, total_rewards3, local_steps_mean3, rewards_x3, rewards_y3, black_rewards3] = data
print('Total episodes:', len(total_rewards3))
print('Avg Time taken:', int(np.mean(time_taken3)*1000),  int(np.std(time_taken3)*1000))
print('local_steps_mean is:', int(np.mean(local_steps_mean3)), int(np.std(local_steps_mean3)))
print('% Tracking is:', round(np.mean(local_steps_mean3)/20, 1))


time_taken = np.hstack((time_taken, time_taken2, time_taken3)) 
total_rewards = np.hstack((total_rewards, total_rewards2, total_rewards3)) 
local_steps_mean = np.hstack((local_steps_mean, local_steps_mean2, local_steps_mean3)) 
rewards_x = np.hstack((rewards_x, rewards_x2, rewards_x3)) 
rewards_y = np.hstack((rewards_y, rewards_y2, rewards_y3)) 
black_rewards = np.hstack((black_rewards, black_rewards2, black_rewards3)) 

print('*'*100)

print('Average Reward is:', round(np.mean(total_rewards),2), round(np.std(total_rewards),2))
print('local_steps_mean is:', int(np.mean(local_steps_mean)), int(np.std(local_steps_mean)))
print('rewards_x mean is:', round(np.mean(rewards_x),2), round(np.std(rewards_x),2))
print('rewards_y mean is:', round(np.mean(rewards_y),2), round(np.std(rewards_y),2))
print('black_rewards mean is:', round(np.mean(black_rewards),2), round(np.std(black_rewards),2))


print('*'*50)
#print(round(np.mean(local_steps_mean)/20, 2), int(np.mean(total_rewards)), round(np.mean(rewards_x),2), round(np.mean(rewards_y),2), round(np.mean(black_rewards),2))

print(round(np.mean(local_steps_mean)/20, 1), round(np.mean(rewards_x),2), round(np.mean(rewards_y),2), round(np.mean(black_rewards),2))
# Out:
# File is: data/Train_Supervized_model_50k_240.h5%variable_background_trees_humans%pickle
# **************************************************
# Total episodes: 100
# Avg Time taken: 29 6
# local_steps_mean is: 1562 643
# % Tracking is: 78.1
# **************************************************
# File is: data/Train_Supervized_model_50k_240_2.h5%variable_background_trees_humans%pickle
# **************************************************
# Total episodes: 100
# Avg Time taken: 30 7
# local_steps_mean is: 1568 603
# % Tracking is: 78.4
# File is: data/Train_Supervized_model_50k_240_3.h5%variable_background_trees_humans%pickle
# **************************************************
# Total episodes: 100
# Avg Time taken: 29 4
# local_steps_mean is: 1528 620
# % Tracking is: 76.4
# ****************************************************************************************************
# Average Reward is: 241.83 106.08
# local_steps_mean is: 1553 622
# rewards_x mean is: 0.84 0.12
# ...

# %% [markdown]
# ## 150k_120

# %%
import pickle
import numpy as np

test_setting = 'variable_background_trees_humans'
model_path = 'data/Train_Supervized_model_150k_120.h5'

save_name = model_path +'%'+test_setting +'%pickle'

print('File is:', save_name)

print('*'*50)

with open(save_name, 'rb') as handle:
    data = pickle.load(handle)


[time_taken, total_rewards, local_steps_mean, rewards_x, rewards_y, black_rewards] = data

print('Total episodes:', len(total_rewards))
print('Avg Time taken:', int(np.mean(time_taken)*1000),  int(np.std(time_taken)*1000))
print('local_steps_mean is:', int(np.mean(local_steps_mean)), int(np.std(local_steps_mean)))
print('*'*50)




model_path = 'data/Train_Supervized_model_150k_120_2.h5'
save_name = model_path +'%'+test_setting +'%pickle'
print('File is:', save_name)
print('*'*50)

with open(save_name, 'rb') as handle:
    data = pickle.load(handle)

[time_taken2, total_rewards2, local_steps_mean2, rewards_x2, rewards_y2, black_rewards2] = data
print('Total episodes:', len(total_rewards2))
print('Avg Time taken:', int(np.mean(time_taken2)*1000),  int(np.std(time_taken2)*1000))
print('local_steps_mean is:', int(np.mean(local_steps_mean2)), int(np.std(local_steps_mean2)))


model_path = 'data/Train_Supervized_model_150k_120_3.h5'
save_name = model_path +'%'+test_setting +'%pickle'
print('File is:', save_name)
print('*'*50)

with open(save_name, 'rb') as handle:
    data = pickle.load(handle)

[time_taken3, total_rewards3, local_steps_mean3, rewards_x3, rewards_y3, black_rewards3] = data
print('Total episodes:', len(total_rewards3))
print('Avg Time taken:', int(np.mean(time_taken3)*1000),  int(np.std(time_taken3)*1000))
print('local_steps_mean is:', int(np.mean(local_steps_mean3)), int(np.std(local_steps_mean3)))



time_taken = np.hstack((time_taken, time_taken2, time_taken3)) 
total_rewards = np.hstack((total_rewards, total_rewards2, total_rewards3)) 
local_steps_mean = np.hstack((local_steps_mean, local_steps_mean2, local_steps_mean3)) 
rewards_x = np.hstack((rewards_x, rewards_x2, rewards_x3)) 
rewards_y = np.hstack((rewards_y, rewards_y2, rewards_y3)) 
black_rewards = np.hstack((black_rewards, black_rewards2, black_rewards3)) 

print('*'*100)

print('*'*100)


print('Average Reward is:', round(np.mean(total_rewards),2), round(np.std(total_rewards),2))
print('local_steps_mean is:', int(np.mean(local_steps_mean)), int(np.std(local_steps_mean)))
print('rewards_x mean is:', round(np.mean(rewards_x),2), round(np.std(rewards_x),2))
print('rewards_y mean is:', round(np.mean(rewards_y),2), round(np.std(rewards_y),2))
print('black_rewards mean is:', round(np.mean(black_rewards),2), round(np.std(black_rewards),2))

print('*'*50)

print(round(np.mean(local_steps_mean)/20, 1), round(np.mean(rewards_x),2), round(np.mean(rewards_y),2), round(np.mean(black_rewards),2))
# Out:
# File is: data/Train_Supervized_model_150k_120.h5%variable_background_trees_humans%pickle
# **************************************************
# Total episodes: 100
# Avg Time taken: 31 6
# local_steps_mean is: 1683 548
# **************************************************
# File is: data/Train_Supervized_model_150k_120_2.h5%variable_background_trees_humans%pickle
# **************************************************
# Total episodes: 100
# Avg Time taken: 31 6
# local_steps_mean is: 1694 580
# File is: data/Train_Supervized_model_150k_120_3.h5%variable_background_trees_humans%pickle
# **************************************************
# Total episodes: 100
# Avg Time taken: 30 5
# local_steps_mean is: 1540 633
# ****************************************************************************************************
# ****************************************************************************************************
# Average Reward is: 259.06 106.27
# local_steps_mean is: 1639 592
# ...

# %% [markdown]
# ## 100k_120

# %%
import pickle
import numpy as np

test_setting = 'variable_background_trees_humans'
model_path = 'data/Train_Supervized_model_100k_120.h5'

save_name = model_path +'%'+test_setting +'%pickle'

print('File is:', save_name)

print('*'*50)

with open(save_name, 'rb') as handle:
    data = pickle.load(handle)


[time_taken, total_rewards, local_steps_mean, rewards_x, rewards_y, black_rewards] = data

print('Total episodes:', len(total_rewards))
print('Avg Time taken:', int(np.mean(time_taken)*1000),  int(np.std(time_taken)*1000))
print('local_steps_mean is:', int(np.mean(local_steps_mean)), int(np.std(local_steps_mean)))
print('*'*50)




model_path = 'data/Train_Supervized_model_100k_120_2.h5'
save_name = model_path +'%'+test_setting +'%pickle'
print('File is:', save_name)
print('*'*50)

with open(save_name, 'rb') as handle:
    data = pickle.load(handle)

[time_taken2, total_rewards2, local_steps_mean2, rewards_x2, rewards_y2, black_rewards2] = data
print('Total episodes:', len(total_rewards2))
print('Avg Time taken:', int(np.mean(time_taken2)*1000),  int(np.std(time_taken2)*1000))
print('local_steps_mean is:', int(np.mean(local_steps_mean2)), int(np.std(local_steps_mean2)))




model_path = 'data/Train_Supervized_model_100k_120_3.h5'
save_name = model_path +'%'+test_setting +'%pickle'
print('File is:', save_name)
print('*'*50)

with open(save_name, 'rb') as handle:
    data = pickle.load(handle)

[time_taken3, total_rewards3, local_steps_mean3, rewards_x3, rewards_y3, black_rewards3] = data
print('Total episodes:', len(total_rewards3))
print('Avg Time taken:', int(np.mean(time_taken3)*1000),  int(np.std(time_taken3)*1000))
print('local_steps_mean is:', int(np.mean(local_steps_mean3)), int(np.std(local_steps_mean3)))



time_taken = np.hstack((time_taken, time_taken2, time_taken3)) 
total_rewards = np.hstack((total_rewards, total_rewards2, total_rewards3)) 
local_steps_mean = np.hstack((local_steps_mean, local_steps_mean2, local_steps_mean3)) 
rewards_x = np.hstack((rewards_x, rewards_x2, rewards_x3)) 
rewards_y = np.hstack((rewards_y, rewards_y2, rewards_y3)) 
black_rewards = np.hstack((black_rewards, black_rewards2, black_rewards3)) 

print('*'*100)






print('Average Reward is:', round(np.mean(total_rewards),2), round(np.std(total_rewards),2))
print('local_steps_mean is:', int(np.mean(local_steps_mean)), int(np.std(local_steps_mean)))
print('rewards_x mean is:', round(np.mean(rewards_x),2), round(np.std(rewards_x),2))
print('rewards_y mean is:', round(np.mean(rewards_y),2), round(np.std(rewards_y),2))
print('black_rewards mean is:', round(np.mean(black_rewards),2), round(np.std(black_rewards),2))

print('*'*50)

print(round(np.mean(local_steps_mean)/20, 1), round(np.mean(rewards_x),2), round(np.mean(rewards_y),2), round(np.mean(black_rewards),2))
# Out:
# File is: data/Train_Supervized_model_100k_120.h5%variable_background_trees_humans%pickle
# **************************************************
# Total episodes: 100
# Avg Time taken: 30 5
# local_steps_mean is: 1578 594
# **************************************************
# File is: data/Train_Supervized_model_100k_120_2.h5%variable_background_trees_humans%pickle
# **************************************************
# Total episodes: 100
# Avg Time taken: 30 2
# local_steps_mean is: 1738 476
# File is: data/Train_Supervized_model_100k_120_3.h5%variable_background_trees_humans%pickle
# **************************************************
# Total episodes: 99
# Avg Time taken: 31 4
# local_steps_mean is: 1587 594
# ****************************************************************************************************
# Average Reward is: 255.9 99.76
# local_steps_mean is: 1635 562
# rewards_x mean is: 0.85 0.12
# rewards_y mean is: 0.84 0.13
# black_rewards mean is: 0.27 0.1
# ...

# %% [markdown]
# ## 50k_120

# %%
import pickle
import numpy as np

test_setting = 'variable_background_trees_humans'
model_path = 'data/Train_Supervized_model_50k_120.h5'

save_name = model_path +'%'+test_setting +'%pickle'

print('File is:', save_name)

print('*'*50)

with open(save_name, 'rb') as handle:
    data = pickle.load(handle)


[time_taken, total_rewards, local_steps_mean, rewards_x, rewards_y, black_rewards] = data

print('Total episodes:', len(total_rewards))
print('Avg Time taken:', int(np.mean(time_taken)*1000),  int(np.std(time_taken)*1000))
print('local_steps_mean is:', int(np.mean(local_steps_mean)), int(np.std(local_steps_mean)))

print('*'*50)




model_path = 'data/Train_Supervized_model_50k_120_2.h5'
save_name = model_path +'%'+test_setting +'%pickle'
print('File is:', save_name)
print('*'*50)

with open(save_name, 'rb') as handle:
    data = pickle.load(handle)

[time_taken2, total_rewards2, local_steps_mean2, rewards_x2, rewards_y2, black_rewards2] = data
print('Total episodes:', len(total_rewards2))
print('Avg Time taken:', int(np.mean(time_taken2)*1000),  int(np.std(time_taken2)*1000))
print('local_steps_mean is:', int(np.mean(local_steps_mean2)), int(np.std(local_steps_mean2)))



model_path = 'data/Train_Supervized_model_50k_120_3.h5'
save_name = model_path +'%'+test_setting +'%pickle'
print('File is:', save_name)
print('*'*50)

with open(save_name, 'rb') as handle:
    data = pickle.load(handle)

[time_taken3, total_rewards3, local_steps_mean3, rewards_x3, rewards_y3, black_rewards3] = data
print('Total episodes:', len(total_rewards3))
print('Avg Time taken:', int(np.mean(time_taken3)*1000),  int(np.std(time_taken3)*1000))
print('local_steps_mean is:', int(np.mean(local_steps_mean3)), int(np.std(local_steps_mean3)))



time_taken = np.hstack((time_taken, time_taken2, time_taken3)) 
total_rewards = np.hstack((total_rewards, total_rewards2, total_rewards3)) 
local_steps_mean = np.hstack((local_steps_mean, local_steps_mean2, local_steps_mean3)) 
rewards_x = np.hstack((rewards_x, rewards_x2, rewards_x3)) 
rewards_y = np.hstack((rewards_y, rewards_y2, rewards_y3)) 
black_rewards = np.hstack((black_rewards, black_rewards2, black_rewards3)) 

print('*'*100)




print('Average Reward is:', round(np.mean(total_rewards),2), round(np.std(total_rewards),2))
print('local_steps_mean is:', int(np.mean(local_steps_mean)), int(np.std(local_steps_mean)))
print('rewards_x mean is:', round(np.mean(rewards_x),2), round(np.std(rewards_x),2))
print('rewards_y mean is:', round(np.mean(rewards_y),2), round(np.std(rewards_y),2))
print('black_rewards mean is:', round(np.mean(black_rewards),2), round(np.std(black_rewards),2))

print('*'*50)
#print(round(np.mean(local_steps_mean)/20, 2), int(np.mean(total_rewards)), round(np.mean(rewards_x),2), round(np.mean(rewards_y),2), round(np.mean(black_rewards),2))

print(round(np.mean(local_steps_mean)/20, 1), round(np.mean(rewards_x),2), round(np.mean(rewards_y),2), round(np.mean(black_rewards),2))
# Out:
# File is: data/Train_Supervized_model_50k_120.h5%variable_background_trees_humans%pickle
# **************************************************
# Total episodes: 99
# Avg Time taken: 30 5
# local_steps_mean is: 1564 615
# **************************************************
# File is: data/Train_Supervized_model_50k_120_2.h5%variable_background_trees_humans%pickle
# **************************************************
# Total episodes: 99
# Avg Time taken: 30 2
# local_steps_mean is: 1572 616
# File is: data/Train_Supervized_model_50k_120_3.h5%variable_background_trees_humans%pickle
# **************************************************
# Total episodes: 100
# Avg Time taken: 31 3
# local_steps_mean is: 1572 640
# ****************************************************************************************************
# Average Reward is: 242.62 105.78
# local_steps_mean is: 1569 624
# rewards_x mean is: 0.84 0.12
# rewards_y mean is: 0.84 0.13
# black_rewards mean is: 0.27 0.11
# ...

# %% [markdown]
# # Simple Backgrounds

# %% [markdown]
# # 240_150k

# %%
import pickle
import numpy as np

test_setting = 'fixed_background'

model_path = 'data/Train_Supervized_model_150k_240.h5'
save_name = model_path +'%'+test_setting +'%pickle'
print('File is:', save_name)
print('*'*50)

with open(save_name, 'rb') as handle:
    data = pickle.load(handle)

[time_taken, total_rewards, local_steps_mean, rewards_x, rewards_y, black_rewards] = data
print('Total episodes:', len(total_rewards))
print('Avg Time taken:', int(np.mean(time_taken)*1000),  int(np.std(time_taken)*1000))
print('local_steps_mean is:', int(np.mean(local_steps_mean)), int(np.std(local_steps_mean)))
print('% Tracking is:', round(np.mean(local_steps_mean)/20, 1))

model_path = 'data/Train_Supervized_model_150k_240_2.h5'
save_name = model_path +'%'+test_setting +'%pickle'
print('File is:', save_name)
print('*'*50)

with open(save_name, 'rb') as handle:
    data = pickle.load(handle)

[time_taken2, total_rewards2, local_steps_mean2, rewards_x2, rewards_y2, black_rewards2] = data
print('Total episodes:', len(total_rewards2))
print('Avg Time taken:', int(np.mean(time_taken2)*1000),  int(np.std(time_taken2)*1000))
print('local_steps_mean is:', int(np.mean(local_steps_mean2)), int(np.std(local_steps_mean2)))
print('% Tracking is:', round(np.mean(local_steps_mean2)/20, 1))

model_path = 'data/Train_Supervized_model_150k_240_3.h5'
save_name = model_path +'%'+test_setting +'%pickle'
print('File is:', save_name)
print('*'*50)

with open(save_name, 'rb') as handle:
    data = pickle.load(handle)

[time_taken3, total_rewards3, local_steps_mean3, rewards_x3, rewards_y3, black_rewards3] = data
print('Total episodes:', len(total_rewards3))
print('Avg Time taken:', int(np.mean(time_taken3)*1000),  int(np.std(time_taken3)*1000))
print('local_steps_mean is:', int(np.mean(local_steps_mean3)), int(np.std(local_steps_mean3)))
print('% Tracking is:', round(np.mean(local_steps_mean3)/20, 1))


time_taken = np.hstack((time_taken, time_taken2, time_taken3)) 
total_rewards = np.hstack((total_rewards, total_rewards2, total_rewards3)) 
local_steps_mean = np.hstack((local_steps_mean, local_steps_mean2, local_steps_mean3)) 
rewards_x = np.hstack((rewards_x, rewards_x2, rewards_x3)) 
rewards_y = np.hstack((rewards_y, rewards_y2, rewards_y3)) 
black_rewards = np.hstack((black_rewards, black_rewards2, black_rewards3)) 

print('*'*100)

print('*'*100)


print('Total episodes:', len(total_rewards))
print('Avg Time taken:', int(np.mean(time_taken)*1000),  int(np.std(time_taken)*1000))
print('*'*50)

print('Average Reward is:', round(np.mean(total_rewards),2), round(np.std(total_rewards),2))
print('local_steps_mean is:', int(np.mean(local_steps_mean)), int(np.std(local_steps_mean)))
print('rewards_x mean is:', round(np.mean(rewards_x),2), round(np.std(rewards_x),2))
print('rewards_y mean is:', round(np.mean(rewards_y),2), round(np.std(rewards_y),2))
print('black_rewards mean is:', round(np.mean(black_rewards),2), round(np.std(black_rewards),2))

print('*'*50)
#print(round(np.mean(local_steps_mean)/20, 2), int(np.mean(total_rewards)), round(np.mean(rewards_x),2), round(np.mean(rewards_y),2), round(np.mean(black_rewards),2))

print(round(np.mean(local_steps_mean)/20, 1), round(np.mean(rewards_x),2), round(np.mean(rewards_y),2), round(np.mean(black_rewards),2))
# Out:
# File is: data/Train_Supervized_model_150k_240.h5%fixed_background%pickle
# **************************************************
# Total episodes: 100
# Avg Time taken: 30 4
# local_steps_mean is: 1954 213
# % Tracking is: 97.7
# File is: data/Train_Supervized_model_150k_240_2.h5%fixed_background%pickle
# **************************************************
# Total episodes: 99
# Avg Time taken: 31 5
# local_steps_mean is: 1968 189
# % Tracking is: 98.4
# File is: data/Train_Supervized_model_150k_240_3.h5%fixed_background%pickle
# **************************************************
# Total episodes: 100
# Avg Time taken: 30 5
# local_steps_mean is: 1943 232
# % Tracking is: 97.2
# ****************************************************************************************************
# ****************************************************************************************************
# Total episodes: 299
# Avg Time taken: 30 5
# **************************************************
# ...

# %% [markdown]
# # 240_100k

# %%
import pickle
import numpy as np

test_setting = 'fixed_background'

model_path = 'data/Train_Supervized_model_100k_240.h5'

save_name = model_path +'%'+test_setting +'%pickle'

print('File is:', save_name)

print('*'*50)

with open(save_name, 'rb') as handle:
    data = pickle.load(handle)


[time_taken, total_rewards, local_steps_mean, rewards_x, rewards_y, black_rewards] = data

print('Total episodes:', len(total_rewards))
print('Avg Time taken:', int(np.mean(time_taken)*1000),  int(np.std(time_taken)*1000))
print('local_steps_mean is:', int(np.mean(local_steps_mean)), int(np.std(local_steps_mean)))
print('% Tracking is:', round(np.mean(local_steps_mean)/20, 1))

print('*'*50)



model_path = 'data/Train_Supervized_model_100k_240_2.h5'
save_name = model_path +'%'+test_setting +'%pickle'
print('File is:', save_name)
print('*'*50)

with open(save_name, 'rb') as handle:
    data = pickle.load(handle)

[time_taken2, total_rewards2, local_steps_mean2, rewards_x2, rewards_y2, black_rewards2] = data
print('Total episodes:', len(total_rewards2))
print('Avg Time taken:', int(np.mean(time_taken2)*1000),  int(np.std(time_taken2)*1000))
print('local_steps_mean is:', int(np.mean(local_steps_mean2)), int(np.std(local_steps_mean2)))
print('% Tracking is:', round(np.mean(local_steps_mean2)/20, 1))




model_path = 'data/Train_Supervized_model_100k_240_3.h5'
save_name = model_path +'%'+test_setting +'%pickle'
print('File is:', save_name)
print('*'*50)

with open(save_name, 'rb') as handle:
    data = pickle.load(handle)

[time_taken3, total_rewards3, local_steps_mean3, rewards_x3, rewards_y3, black_rewards3] = data
print('Total episodes:', len(total_rewards3))
print('Avg Time taken:', int(np.mean(time_taken3)*1000),  int(np.std(time_taken3)*1000))
print('local_steps_mean is:', int(np.mean(local_steps_mean3)), int(np.std(local_steps_mean3)))
print('black_rewards mean is:', round(np.mean(black_rewards3),2), round(np.std(black_rewards3),2))
print('% Tracking is:', round(np.mean(local_steps_mean3)/20, 1))



time_taken = np.hstack((time_taken, time_taken2, time_taken3)) 
total_rewards = np.hstack((total_rewards, total_rewards2, total_rewards3)) 
local_steps_mean = np.hstack((local_steps_mean, local_steps_mean2, local_steps_mean3)) 
rewards_x = np.hstack((rewards_x, rewards_x2, rewards_x3)) 
rewards_y = np.hstack((rewards_y, rewards_y2, rewards_y3)) 
black_rewards = np.hstack((black_rewards, black_rewards2, black_rewards3)) 

print('*'*100)


print('*'*100)



print('Average Reward is:', round(np.mean(total_rewards),2), round(np.std(total_rewards),2))
print('local_steps_mean is:', int(np.mean(local_steps_mean)), int(np.std(local_steps_mean)))
print('rewards_x mean is:', round(np.mean(rewards_x),2), round(np.std(rewards_x),2))
print('rewards_y mean is:', round(np.mean(rewards_y),2), round(np.std(rewards_y),2))
print('black_rewards mean is:', round(np.mean(black_rewards),2), round(np.std(black_rewards),2))

print('*'*50)
#print(round(np.mean(local_steps_mean)/20, 2), int(np.mean(total_rewards)), round(np.mean(rewards_x),2), round(np.mean(rewards_y),2), round(np.mean(black_rewards),2))

print(round(np.mean(local_steps_mean)/20, 1), round(np.mean(rewards_x),2), round(np.mean(rewards_y),2), round(np.mean(black_rewards),2))
# Out:
# File is: data/Train_Supervized_model_100k_240.h5%fixed_background%pickle
# **************************************************
# Total episodes: 100
# Avg Time taken: 31 4
# local_steps_mean is: 1950 216
# % Tracking is: 97.5
# **************************************************
# File is: data/Train_Supervized_model_100k_240_2.h5%fixed_background%pickle
# **************************************************
# Total episodes: 100
# Avg Time taken: 30 4
# local_steps_mean is: 1974 171
# % Tracking is: 98.7
# File is: data/Train_Supervized_model_100k_240_3.h5%fixed_background%pickle
# **************************************************
# Total episodes: 100
# Avg Time taken: 30 4
# local_steps_mean is: 1952 268
# black_rewards mean is: 0.32 0.12
# % Tracking is: 97.6
# ****************************************************************************************************
# ****************************************************************************************************
# ...

# %% [markdown]
# # 240_50k

# %%
import pickle
import numpy as np

test_setting = 'fixed_background'

model_path = 'data/Train_Supervized_model_50k_240.h5'

save_name = model_path +'%'+test_setting +'%pickle'



print('File is:', save_name)

print('*'*50)

with open(save_name, 'rb') as handle:
    data = pickle.load(handle)


[time_taken, total_rewards, local_steps_mean, rewards_x, rewards_y, black_rewards] = data

print('Total episodes:', len(total_rewards))
print('Avg Time taken:', int(np.mean(time_taken)*1000),  int(np.std(time_taken)*1000))
print('local_steps_mean is:', int(np.mean(local_steps_mean)), int(np.std(local_steps_mean)))
print('% Tracking is:', round(np.mean(local_steps_mean)/20, 1))

print('*'*50)



model_path = 'data/Train_Supervized_model_50k_240_2.h5'
save_name = model_path +'%'+test_setting +'%pickle'
print('File is:', save_name)
print('*'*50)

with open(save_name, 'rb') as handle:
    data = pickle.load(handle)

[time_taken2, total_rewards2, local_steps_mean2, rewards_x2, rewards_y2, black_rewards2] = data
print('Total episodes:', len(total_rewards2))
print('Avg Time taken:', int(np.mean(time_taken2)*1000),  int(np.std(time_taken2)*1000))
print('local_steps_mean is:', int(np.mean(local_steps_mean2)), int(np.std(local_steps_mean2)))
print('% Tracking is:', round(np.mean(local_steps_mean2)/20, 1))



model_path = 'data/Train_Supervized_model_50k_240_3.h5'
save_name = model_path +'%'+test_setting +'%pickle'
print('File is:', save_name)
print('*'*50)

with open(save_name, 'rb') as handle:
    data = pickle.load(handle)

[time_taken3, total_rewards3, local_steps_mean3, rewards_x3, rewards_y3, black_rewards3] = data
print('Total episodes:', len(total_rewards3))
print('Avg Time taken:', int(np.mean(time_taken3)*1000),  int(np.std(time_taken3)*1000))
print('local_steps_mean is:', int(np.mean(local_steps_mean3)), int(np.std(local_steps_mean3)))
print('% Tracking is:', round(np.mean(local_steps_mean3)/20, 1))


time_taken = np.hstack((time_taken, time_taken2, time_taken3)) 
total_rewards = np.hstack((total_rewards, total_rewards2, total_rewards3)) 
local_steps_mean = np.hstack((local_steps_mean, local_steps_mean2, local_steps_mean3)) 
rewards_x = np.hstack((rewards_x, rewards_x2, rewards_x3)) 
rewards_y = np.hstack((rewards_y, rewards_y2, rewards_y3)) 
black_rewards = np.hstack((black_rewards, black_rewards2, black_rewards3)) 

print('*'*100)

print('Average Reward is:', round(np.mean(total_rewards),2), round(np.std(total_rewards),2))
print('local_steps_mean is:', int(np.mean(local_steps_mean)), int(np.std(local_steps_mean)))
print('rewards_x mean is:', round(np.mean(rewards_x),2), round(np.std(rewards_x),2))
print('rewards_y mean is:', round(np.mean(rewards_y),2), round(np.std(rewards_y),2))
print('black_rewards mean is:', round(np.mean(black_rewards),2), round(np.std(black_rewards),2))


print('*'*50)
#print(round(np.mean(local_steps_mean)/20, 2), int(np.mean(total_rewards)), round(np.mean(rewards_x),2), round(np.mean(rewards_y),2), round(np.mean(black_rewards),2))

print(round(np.mean(local_steps_mean)/20, 1), round(np.mean(rewards_x),2), round(np.mean(rewards_y),2), round(np.mean(black_rewards),2))
# Out:
# File is: data/Train_Supervized_model_50k_240.h5%fixed_background%pickle
# **************************************************
# Total episodes: 100
# Avg Time taken: 31 4
# local_steps_mean is: 1938 269
# % Tracking is: 96.9
# **************************************************
# File is: data/Train_Supervized_model_50k_240_2.h5%fixed_background%pickle
# **************************************************
# Total episodes: 100
# Avg Time taken: 30 5
# local_steps_mean is: 1980 139
# % Tracking is: 99.0
# File is: data/Train_Supervized_model_50k_240_3.h5%fixed_background%pickle
# **************************************************
# Total episodes: 100
# Avg Time taken: 30 4
# local_steps_mean is: 1939 274
# % Tracking is: 97.0
# ****************************************************************************************************
# Average Reward is: 315.7 59.99
# local_steps_mean is: 1952 237
# rewards_x mean is: 0.85 0.12
# rewards_y mean is: 0.84 0.13
# black_rewards mean is: 0.3 0.11
# ...

# %% [markdown]
# # 120_150k

# %%
import pickle
import numpy as np

test_setting = 'fixed_background'

model_path = 'data/Train_Supervized_model_150k_120.h5'

save_name = model_path +'%'+test_setting +'%pickle'

print('File is:', save_name)

print('*'*50)

with open(save_name, 'rb') as handle:
    data = pickle.load(handle)


[time_taken, total_rewards, local_steps_mean, rewards_x, rewards_y, black_rewards] = data

print('Total episodes:', len(total_rewards))
print('Avg Time taken:', int(np.mean(time_taken)*1000),  int(np.std(time_taken)*1000))
print('local_steps_mean is:', int(np.mean(local_steps_mean)), int(np.std(local_steps_mean)))
print('% Tracking is:', round(np.mean(local_steps_mean)/20, 1))

print('*'*50)




model_path = 'data/Train_Supervized_model_150k_120_2.h5'
save_name = model_path +'%'+test_setting +'%pickle'
print('File is:', save_name)
print('*'*50)

with open(save_name, 'rb') as handle:
    data = pickle.load(handle)

[time_taken2, total_rewards2, local_steps_mean2, rewards_x2, rewards_y2, black_rewards2] = data
print('Total episodes:', len(total_rewards2))
print('Avg Time taken:', int(np.mean(time_taken2)*1000),  int(np.std(time_taken2)*1000))
print('local_steps_mean is:', int(np.mean(local_steps_mean2)), int(np.std(local_steps_mean2)))
print('% Tracking is:', round(np.mean(local_steps_mean2)/20, 1))


model_path = 'data/Train_Supervized_model_150k_120_3.h5'
save_name = model_path +'%'+test_setting +'%pickle'
print('File is:', save_name)
print('*'*50)

with open(save_name, 'rb') as handle:
    data = pickle.load(handle)

[time_taken3, total_rewards3, local_steps_mean3, rewards_x3, rewards_y3, black_rewards3] = data
print('Total episodes:', len(total_rewards3))
print('Avg Time taken:', int(np.mean(time_taken3)*1000),  int(np.std(time_taken3)*1000))
print('local_steps_mean is:', int(np.mean(local_steps_mean3)), int(np.std(local_steps_mean3)))
print('% Tracking is:', round(np.mean(local_steps_mean3)/20, 1))


time_taken = np.hstack((time_taken, time_taken2, time_taken3)) 
total_rewards = np.hstack((total_rewards, total_rewards2, total_rewards3)) 
local_steps_mean = np.hstack((local_steps_mean, local_steps_mean2, local_steps_mean3)) 
rewards_x = np.hstack((rewards_x, rewards_x2, rewards_x3)) 
rewards_y = np.hstack((rewards_y, rewards_y2, rewards_y3)) 
black_rewards = np.hstack((black_rewards, black_rewards2, black_rewards3)) 

print('*'*100)

print('*'*100)


print('Average Reward is:', round(np.mean(total_rewards),2), round(np.std(total_rewards),2))
print('local_steps_mean is:', int(np.mean(local_steps_mean)), int(np.std(local_steps_mean)))
print('rewards_x mean is:', round(np.mean(rewards_x),2), round(np.std(rewards_x),2))
print('rewards_y mean is:', round(np.mean(rewards_y),2), round(np.std(rewards_y),2))
print('black_rewards mean is:', round(np.mean(black_rewards),2), round(np.std(black_rewards),2))

print('*'*50)
#print(round(np.mean(local_steps_mean)/20, 2), int(np.mean(total_rewards)), round(np.mean(rewards_x),2), round(np.mean(rewards_y),2), round(np.mean(black_rewards),2))

print(round(np.mean(local_steps_mean)/20, 1), round(np.mean(rewards_x),2), round(np.mean(rewards_y),2), round(np.mean(black_rewards),2))
# Out:
# File is: data/Train_Supervized_model_150k_120.h5%fixed_background%pickle
# **************************************************
# Total episodes: 100
# Avg Time taken: 31 4
# local_steps_mean is: 1934 271
# % Tracking is: 96.7
# **************************************************
# File is: data/Train_Supervized_model_150k_120_2.h5%fixed_background%pickle
# **************************************************
# Total episodes: 100
# Avg Time taken: 31 5
# local_steps_mean is: 1971 164
# % Tracking is: 98.6
# File is: data/Train_Supervized_model_150k_120_3.h5%fixed_background%pickle
# **************************************************
# Total episodes: 100
# Avg Time taken: 31 5
# local_steps_mean is: 1963 200
# % Tracking is: 98.2
# ****************************************************************************************************
# ****************************************************************************************************
# Average Reward is: 317.57 56.87
# ...

# %% [markdown]
# # 120_100k

# %%
import pickle
import numpy as np

test_setting = 'fixed_background'

model_path = 'data/Train_Supervized_model_100k_120.h5'

save_name = model_path +'%'+test_setting +'%pickle'

print('File is:', save_name)

print('*'*50)

with open(save_name, 'rb') as handle:
    data = pickle.load(handle)


[time_taken, total_rewards, local_steps_mean, rewards_x, rewards_y, black_rewards] = data

print('Total episodes:', len(total_rewards))
print('Avg Time taken:', int(np.mean(time_taken)*1000),  int(np.std(time_taken)*1000))
print('local_steps_mean is:', int(np.mean(local_steps_mean)), int(np.std(local_steps_mean)))
print('% Tracking is:', round(np.mean(local_steps_mean)/20, 1))

print('*'*50)




model_path = 'data/Train_Supervized_model_100k_120_2.h5'
save_name = model_path +'%'+test_setting +'%pickle'
print('File is:', save_name)
print('*'*50)

with open(save_name, 'rb') as handle:
    data = pickle.load(handle)

[time_taken2, total_rewards2, local_steps_mean2, rewards_x2, rewards_y2, black_rewards2] = data
print('Total episodes:', len(total_rewards2))
print('Avg Time taken:', int(np.mean(time_taken2)*1000),  int(np.std(time_taken2)*1000))
print('local_steps_mean is:', int(np.mean(local_steps_mean2)), int(np.std(local_steps_mean2)))
print('% Tracking is:', round(np.mean(local_steps_mean2)/20, 1))




model_path = 'data/Train_Supervized_model_100k_120_3.h5'
save_name = model_path +'%'+test_setting +'%pickle'
print('File is:', save_name)
print('*'*50)

with open(save_name, 'rb') as handle:
    data = pickle.load(handle)

[time_taken3, total_rewards3, local_steps_mean3, rewards_x3, rewards_y3, black_rewards3] = data
print('Total episodes:', len(total_rewards3))
print('Avg Time taken:', int(np.mean(time_taken3)*1000),  int(np.std(time_taken3)*1000))
print('local_steps_mean is:', int(np.mean(local_steps_mean3)), int(np.std(local_steps_mean3)))
print('% Tracking is:', round(np.mean(local_steps_mean3)/20, 1))



time_taken = np.hstack((time_taken, time_taken2, time_taken3)) 
total_rewards = np.hstack((total_rewards, total_rewards2, total_rewards3)) 
local_steps_mean = np.hstack((local_steps_mean, local_steps_mean2, local_steps_mean3)) 
rewards_x = np.hstack((rewards_x, rewards_x2, rewards_x3)) 
rewards_y = np.hstack((rewards_y, rewards_y2, rewards_y3)) 
black_rewards = np.hstack((black_rewards, black_rewards2, black_rewards3)) 

print('*'*100)






print('Average Reward is:', round(np.mean(total_rewards),2), round(np.std(total_rewards),2))
print('local_steps_mean is:', int(np.mean(local_steps_mean)), int(np.std(local_steps_mean)))
print('%tracking is:', (np.mean(local_steps_mean)/20), int(np.std(local_steps_mean)/20))
print('rewards_x mean is:', round(np.mean(rewards_x),2), round(np.std(rewards_x),2))
print('rewards_y mean is:', round(np.mean(rewards_y),2), round(np.std(rewards_y),2))
print('black_rewards mean is:', round(np.mean(black_rewards),2), round(np.std(black_rewards),2))

print('*'*50)
#print(round(np.mean(local_steps_mean)/20, 2), int(np.mean(total_rewards)), round(np.mean(rewards_x),2), round(np.mean(rewards_y),2), round(np.mean(black_rewards),2))

print(round(np.mean(local_steps_mean)/20, 1), round(np.mean(rewards_x),2), round(np.mean(rewards_y),2), round(np.mean(black_rewards),2))
# Out:
# File is: data/Train_Supervized_model_100k_120.h5%fixed_background%pickle
# **************************************************
# Total episodes: 100
# Avg Time taken: 31 4
# local_steps_mean is: 1983 119
# % Tracking is: 99.2
# **************************************************
# File is: data/Train_Supervized_model_100k_120_2.h5%fixed_background%pickle
# **************************************************
# Total episodes: 100
# Avg Time taken: 31 4
# local_steps_mean is: 1943 277
# % Tracking is: 97.2
# File is: data/Train_Supervized_model_100k_120_3.h5%fixed_background%pickle
# **************************************************
# Total episodes: 100
# Avg Time taken: 30 4
# local_steps_mean is: 1976 169
# % Tracking is: 98.8
# ****************************************************************************************************
# Average Reward is: 314.88 55.36
# local_steps_mean is: 1967 200
# %tracking is: 98.392 10
# rewards_x mean is: 0.84 0.11
# rewards_y mean is: 0.84 0.12
# ...

# %% [markdown]
# # 120_50k

# %%
import pickle
import numpy as np

test_setting = 'fixed_background'

model_path = 'data/Train_Supervized_model_50k_120.h5'

save_name = model_path +'%'+test_setting +'%pickle'

print('File is:', save_name)

print('*'*50)

with open(save_name, 'rb') as handle:
    data = pickle.load(handle)


[time_taken, total_rewards, local_steps_mean, rewards_x, rewards_y, black_rewards] = data

print('Total episodes:', len(total_rewards))
print('Avg Time taken:', int(np.mean(time_taken)*1000),  int(np.std(time_taken)*1000))
print('local_steps_mean is:', int(np.mean(local_steps_mean)), int(np.std(local_steps_mean)))
print('% Tracking is:', round(np.mean(local_steps_mean)/20, 1))

print('*'*50)




model_path = 'data/Train_Supervized_model_50k_120_2.h5'
save_name = model_path +'%'+test_setting +'%pickle'
print('File is:', save_name)
print('*'*50)

with open(save_name, 'rb') as handle:
    data = pickle.load(handle)

[time_taken2, total_rewards2, local_steps_mean2, rewards_x2, rewards_y2, black_rewards2] = data
print('Total episodes:', len(total_rewards2))
print('Avg Time taken:', int(np.mean(time_taken2)*1000),  int(np.std(time_taken2)*1000))
print('local_steps_mean is:', int(np.mean(local_steps_mean2)), int(np.std(local_steps_mean2)))
print('% Tracking is:', round(np.mean(local_steps_mean2)/20, 1))



model_path = 'data/Train_Supervized_model_50k_120_3.h5'
save_name = model_path +'%'+test_setting +'%pickle'
print('File is:', save_name)
print('*'*50)

with open(save_name, 'rb') as handle:
    data = pickle.load(handle)

[time_taken3, total_rewards3, local_steps_mean3, rewards_x3, rewards_y3, black_rewards3] = data
print('Total episodes:', len(total_rewards3))
print('Avg Time taken:', int(np.mean(time_taken3)*1000),  int(np.std(time_taken3)*1000))
print('local_steps_mean is:', int(np.mean(local_steps_mean3)), int(np.std(local_steps_mean3)))
print('% Tracking is:', round(np.mean(local_steps_mean3)/20, 1))



time_taken = np.hstack((time_taken, time_taken2, time_taken3)) 
total_rewards = np.hstack((total_rewards, total_rewards2, total_rewards3)) 
local_steps_mean = np.hstack((local_steps_mean, local_steps_mean2, local_steps_mean3)) 
rewards_x = np.hstack((rewards_x, rewards_x2, rewards_x3)) 
rewards_y = np.hstack((rewards_y, rewards_y2, rewards_y3)) 
black_rewards = np.hstack((black_rewards, black_rewards2, black_rewards3)) 

print('*'*100)



print('Average Reward is:', round(np.mean(total_rewards),2), round(np.std(total_rewards),2))
print('local_steps_mean is:', int(np.mean(local_steps_mean)), int(np.std(local_steps_mean)))
print('rewards_x mean is:', round(np.mean(rewards_x),2), round(np.std(rewards_x),2))
print('rewards_y mean is:', round(np.mean(rewards_y),2), round(np.std(rewards_y),2))
print('black_rewards mean is:', round(np.mean(black_rewards),2), round(np.std(black_rewards),2))

print('*'*50)

print(round(np.mean(local_steps_mean)/20, 1), round(np.mean(rewards_x),2), round(np.mean(rewards_y),2), round(np.mean(black_rewards),2))
# Out:
# File is: data/Train_Supervized_model_50k_120.h5%fixed_background%pickle
# **************************************************
# Total episodes: 100
# Avg Time taken: 31 4
# local_steps_mean is: 1958 220
# % Tracking is: 97.9
# **************************************************
# File is: data/Train_Supervized_model_50k_120_2.h5%fixed_background%pickle
# **************************************************
# Total episodes: 100
# Avg Time taken: 30 4
# local_steps_mean is: 1957 241
# % Tracking is: 97.9
# File is: data/Train_Supervized_model_50k_120_3.h5%fixed_background%pickle
# **************************************************
# Total episodes: 100
# Avg Time taken: 31 4
# local_steps_mean is: 1983 138
# % Tracking is: 99.2
# ****************************************************************************************************
# Average Reward is: 321.11 54.45
# local_steps_mean is: 1966 205
# rewards_x mean is: 0.85 0.12
# rewards_y mean is: 0.84 0.12
# ...
